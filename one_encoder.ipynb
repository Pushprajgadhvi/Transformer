# %% [markdown]
# ## custome layer normalization

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F 
import math

# %%
import torch
import torch.nn as nn
import math

class CustomLayerNorm(nn.Module):
    def __init__(self, embed_size, eps=1e-6):
        super().__init__()
        self.gamma = nn.Parameter(torch.ones(embed_size))
        self.beta = nn.Parameter(torch.zeros(embed_size))
        self.eps = eps

    def forward(self, x):
        # x shape: (batch, seq_len, embed_size)
        mean = x.mean(dim=-1, keepdim=True)
        variance = x.var(dim=-1, keepdim=True, unbiased=False)

        x_norm = (x - mean) / torch.sqrt(variance + self.eps)
        return self.gamma * x_norm + self.beta


# Test
x = torch.randn(2, 5, 512)
ln = CustomLayerNorm(512)
print(ln(x).shape)
# Out:
# torch.Size([2, 5, 512])
