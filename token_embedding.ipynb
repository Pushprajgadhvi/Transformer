# %% [markdown]
# ## Token Embedding

# %%
import torch
import torch.nn as nn

class TokenEmbedding(nn.Module):
    def __init__(self, vocab_size, d_model):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, d_model)

    def forward(self, x):
        return self.embedding(x)


# TEST
vocab_size = 100
d_model = 16

embed = TokenEmbedding(vocab_size, d_model)

x = torch.tensor([[1,5,9,3]])

out = embed(x)

print("Input shape:", x.shape)
print("Output shape:", out.shape)
print(out)
# Out:
# Input shape: torch.Size([1, 4])
# Output shape: torch.Size([1, 4, 16])
# tensor([[[-0.2261, -0.8055,  0.0430,  1.4238,  0.5154, -1.9024, -0.4442,
#           -1.8094,  0.4708, -2.0155, -0.2224, -0.0911, -0.0892,  1.8469,
#           -1.5812, -0.5327],
#          [ 2.5420,  0.1398,  0.2604,  0.8067, -1.3236, -0.6776,  0.5085,
#            0.4264,  1.1010, -0.4640, -0.4363,  0.7686, -0.0666,  0.2353,
#            0.7961, -0.5711],
#          [-0.1105,  1.4114, -0.8701, -1.0728, -1.2695,  1.2704, -1.4972,
#           -0.2156, -0.1438, -0.1930,  1.7834, -0.3798, -0.1204, -0.4919,
#           -0.5061, -0.3829],
#          [-1.4175,  0.4107, -1.0783, -0.6802,  0.3854, -0.0988, -0.6769,
#           -1.8066,  0.0797,  0.2379,  1.3866, -0.2976,  0.4709,  0.8292,
#            0.8132, -2.0001]]], grad_fn=<EmbeddingBackward0>)
